# %%
import io
import math
import torch
import torchvision
import numpy as np
import torch.nn as nn
import torch.optim as opt
import matplotlib.pyplot as plt
from datasets import load_dataset
from PIL import Image as PILImage
import torchvision.transforms as T
from datasets import Dataset as DatasetData
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, Dataset, TensorDataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
textTransform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(0.5, 0.5)
])

# %%
class CustomPokemonDataset(Dataset):
    def __init__(self, split='train', transform=None):
        self.dataset = load_dataset("lambdalabs/pokemon-blip-captions", split=split)
        self.transform = transform
        self.label_encoder = LabelEncoder()
        unique_captions = set(item["text"] for item in self.dataset)
        self.label_encoder.fit(list(unique_captions))

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        image = item["image"]
        caption = item["text"]
        print(caption, len(item["text"]))

        if self.transform:
            image = self.transform(image)
        # caption = textTransform(caption)
        label = self.label_encoder.transform([caption])[0]

        return image, label

# %%
image_size = (256, 256)
batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
PATCH_SIZE = 128
IMAGE_WIDTH = 256
IMAGE_HEIGHT = IMAGE_WIDTH
IMAGE_CHANNELS = 3
EMBEDDING_DIMS = IMAGE_CHANNELS * PATCH_SIZE ** 2
NUM_OF_PATCHES = int((IMAGE_WIDTH * IMAGE_HEIGHT) / PATCH_SIZE ** 2)

assert IMAGE_WIDTH % PATCH_SIZE == 0 and IMAGE_HEIGHT % PATCH_SIZE == 0, print(
    "Image Width is not divisible by patch size")

# %%
transform = T.Compose([
    T.Resize(image_size),
    T.CenterCrop(image_size),
    T.ToTensor(),
    T.Normalize(0.5, 0.5)
])

# %%
train_dataset = CustomPokemonDataset(split='train', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)

# %%
examples = enumerate(train_loader)
batch_idx, data = next(examples)
print(len(data), data[1])  # 2
# Out:
# a cartoon picture of a small furry animal 41
# a cartoon character is holding a large object 45
# a drawing of an animal with wings and a tail 44
# a picture of a cartoon character in a costume 45
# an image of a cartoon character flying through the air 54
# a cartoon of a deer with a tree on its back 43
# a drawing of a cartoon character holding a flame 48
# a drawing of a spider with big eyes 35
# 2 tensor([242, 135, 541, 590, 728, 214, 319, 503], dtype=torch.int32)

# %%
class MultiHeadAttention(torch.nn.Module):
    r"""Multi-headed Attention for input Query, Key, Value

    Multi-headed Attention is a module for attention mechanisms which runs through attention in several times in
    parallel, then the multiple outputs are concatenated and linearly transformed

    Args:
        embed_size  (int): Max embedding size
        num_heads   (int): Number of heads in multi-headed attention; Number of splits in the embedding size
        dropout     (float, optional): Percentage of Dropout to be applied in range 0 <= dropout <=1
        batch_dim   (int, optional): The dimension in which batch dimensions is

    """

    def __init__(
            self, embed_size: int, num_heads: int, dropout: float = 0.2, batch_dim: int = 0
    ):
        super(MultiHeadAttention, self).__init__()

        self.embed_size = embed_size
        self.num_heads = num_heads
        self.dropout = dropout
        self.batch_dim = batch_dim

        self.dropout_layer = torch.nn.Dropout(dropout)

        self.head_size = self.embed_size // self.num_heads

        assert (
                self.head_size * self.num_heads == self.embed_size
        ), "Heads cannot split Embedding size equally"

        self.Q = torch.nn.Linear(self.embed_size, self.embed_size)
        self.K = torch.nn.Linear(self.embed_size, self.embed_size)
        self.V = torch.nn.Linear(self.embed_size, self.embed_size)

        self.linear = torch.nn.Linear(self.embed_size, self.embed_size)

    def forward(self, q, k, v, mask=None):
        if self.batch_dim == 0:
            out = self.batch_0(q, k, v, mask)
        elif self.batch_dim == 1:
            out = self.batch_1(q, k, v, mask)

        return out

    def batch_0(self, q, k, v, mask=None):
        q_batch_size, q_seq_len, q_embed_size = q.size()
        k_batch_size, k_seq_len, k_embed_size = k.size()
        v_batch_size, v_seq_len, v_embed_size = v.size()

        q = self.Q(q).reshape(q_batch_size, q_seq_len, self.num_heads, self.head_size)
        k = self.K(k).reshape(k_batch_size, k_seq_len, self.num_heads, self.head_size)
        v = self.V(v).reshape(v_batch_size, v_seq_len, self.num_heads, self.head_size)

        attention = self.attention(q, k, v, mask=mask)
        concatenated = attention.reshape(v_batch_size, -1, self.embed_size)
        out = self.linear(concatenated)

        return out

    def batch_1(self, q, k, v, mask=None):
        q_seq_len, q_batch_size, q_embed_size = q.size()
        k_seq_len, k_batch_size, k_embed_size = k.size()
        v_seq_len, v_batch_size, v_embed_size = v.size()

        q = (
            self.Q(q)
            .reshape(q_seq_len, q_batch_size, self.num_heads, self.head_size)
            .transpose(0, 1)
        )
        k = (
            self.K(k)
            .reshape(k_seq_len, k_batch_size, self.num_heads, self.head_size)
            .transpose(0, 1)
        )
        v = (
            self.V(v)
            .reshape(v_seq_len, v_batch_size, self.num_heads, self.head_size)
            .transpose(0, 1)
        )

        attention = self.attention(q, k, v, mask=mask)
        concatenated = attention.reshape(-1, v_batch_size, self.embed_size)

        out = self.linear(concatenated)

        return out

    def attention(self, q, k, v, mask=None):
        scores = torch.einsum("bqhe,bkhe->bhqk", [q, k])

        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)

        scores /= math.sqrt(self.embed_size)
        scores = torch.nn.functional.softmax(scores, dim=-1)
        scores = self.dropout_layer(scores)
        attention = torch.einsum("bhql,blhd->bqhd", [scores, v])
        return attention

# %%
class VisionEncoder(nn.Module):
    def __init__(self, embed_size, nb_heads, hidden_size, dropout):
        super(VisionEncoder, self).__init__()

        self.attention = torch.nn.MultiheadAttention(
            embed_size, nb_heads, dropout=dropout
        )
        self.mlp = torch.nn.Sequential(
            torch.nn.Linear(embed_size, hidden_size),
            torch.nn.ReLU(),
            torch.nn.Dropout(dropout),
            torch.nn.Linear(hidden_size, embed_size),
        )

        self.norm1 = torch.nn.LayerNorm(embed_size)
        self.norm2 = torch.nn.LayerNorm(embed_size)
        self.dropout = torch.nn.Dropout(dropout)

    def forward(self, x):
        # Attention
        attn_output, _ = self.attention(x, x, x)
        x = x + attn_output
        x = self.norm1(x)
        # MLP
        mlp_output = self.mlp(x)
        x = x + mlp_output
        x = self.norm2(x)
        x = self.dropout(x)

        return x

# %%
class ViT(torch.nn.Module):
    def __init__(
            self,
            image_size,
            channel_size,
            patch_size,
            embed_size,
            nb_heads,
            classes,
            nb_layers,
            hidden_size,
            dropout,
    ):
        super(ViT, self).__init__()

        self.patch_size = patch_size
        self.embed_size = embed_size
        self.nb_patches = int((image_size * image_size) / patch_size ** 2)
        self.pixels_per_patch = channel_size * (patch_size ** 2)
        self.nb_heads = nb_heads
        self.classes = classes
        self.nb_layers = nb_layers
        self.hidden_size = hidden_size
        self.dropout = dropout

        self.patch_embedings = nn.Linear(self.pixels_per_patch, embed_size)
        self.class_token = nn.Parameter(torch.randn(1, 1, embed_size))
        self.positional_encoding = nn.Parameter(
            torch.randn(1, self.nb_patches, embed_size)
        )

        self.encoders = torch.nn.ModuleList(
            [
                VisionEncoder(embed_size, nb_heads, hidden_size, dropout)
                for _ in range(nb_layers)
            ]
        )

        self.classifier = torch.nn.Linear(embed_size, classes)

    def forward(self, img_torch):
        b, c, h, w = img_torch.size()
        img_torch_reshape = img_torch.reshape(
            b,
            int((h / self.patch_size) * (w / self.patch_size)),
            c * self.patch_size * self.patch_size,
        ).float()

        patch_embedings = self.patch_embedings(img_torch_reshape)
        patch_embedings = patch_embedings + self.positional_encoding
        img_with_class_token = torch.cat(
            (self.class_token.expand(b, -1, -1), patch_embedings), dim=1
        )

        for encoder in self.encoders:
            img_with_positional_encoding = encoder(img_with_class_token)

        fwd_cls = img_with_positional_encoding[:, -1, :]

        fwd_norm = torch.nn.LayerNorm(self.embed_size)(fwd_cls)

        fwd_classifier = self.classifier(fwd_norm)

        fwd_softmax = torch.nn.functional.log_softmax(fwd_classifier, dim=-1)

        return fwd_softmax


model = ViT(
    image_size=256,
    channel_size=3,
    patch_size=128,
    embed_size=256,
    nb_heads=8,
    classes=812,
    nb_layers=3,
    hidden_size=256,
    dropout=0.2,
).to(device)

# %%
loss_function = nn.NLLLoss()
optimizer = opt.Adam(model.parameters(), 0.00005)

# %%
losses = []
accuracies = []
nb_epochs = 10
for epoch in range(nb_epochs):
    model.train()

    epoch_loss = 0

    y_pred = []
    y_true = []
    for imgs, labels in train_loader:
        imgs = imgs.to(device)
        labels = labels.to(device).long()  # Convert labels to Long
    
        print("Shape before linear layer:", imgs.shape)
    
        predictions = model(imgs)
    
        loss = loss_function(predictions, labels)
    
        optimizer.zero_grad()
    
        loss.backward()
    
        optimizer.step()
    
        y_pred.extend(predictions.detach().argmax(dim=1).tolist())
        y_true.extend(labels.detach().tolist())
    
        epoch_loss += loss.item()

    losses.append(epoch_loss)

    nb_imgs = len(y_pred)
    total_correct = 0
    for i in range(nb_imgs):
        if y_pred[i] == y_true[i]:
            total_correct += 1
    accuracy = total_correct * 100 / nb_imgs

    accuracies.append(accuracy)

    print("----------")
    print("Epoch:", epoch)
    print("Loss:", epoch_loss)
    print(f"Accuracy: {accuracy} % ({total_correct} / {nb_imgs})")
# Out:
# a green cartoon character with a big smile 42
# a cartoon character with a hat on his head 42
# a picture of a piece of clothing with a scarf on top of it 58
# a cartoon of a white and gray animal 36
# a cartoon bird flying through the air 37
# a cartoon car with a yellow top on it 37
# a drawing of a cartoon character with big eyes 46
# a very cute looking cartoon character with big eyes 51
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of an animal's head with spikes on it 47
# a stylized image of a robot with a helmet on 44
# a drawing of a yellow and black cat 35
# a drawing of a key with a face on it 36
# a drawing of a plant with leaves on it 38
# a cartoon slotty sleeping on its back 37
# a cartoon bird with a pink hat on its head 42
# a bird with a long beak flying through the air 46
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon green lizard with a pink belly 40
# a green and yellow cartoon character holding a flower 53
# a cartoon deer with a yellow bow on its head 44
# a drawing of a blue and yellow pokemon 38
# a drawing of a green and yellow lizard 38
# a very cute looking pokemon with big eyes 41
# a green and yellow toy with a red nose 38
# a cartoon sunflower with a happy face 37
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon monkey holding a stick 45
# a drawing of a green and yellow dragon 38
# a cartoon sheep is holding a hot dog 36
# a blue and white dragon with its mouth open 43
# a drawing of a red and yellow pokemon character 47
# a pikachu holding a cell phone and wearing a bow tie 52
# a drawing of a panda smoking a cigarette 40
# a cartoon character with a crown on his head 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon dinosaur laying on the ground with its mouth open 59
# a green and orange dragon with a long tail 42
# a brown and white animal with a pink nose 41
# a bunch of balls with faces drawn on them 41
# a picture of a white and green monster 38
# a cartoon character flying through the air 42
# a very cute looking pokemon with big wings 42
# a drawing of a cartoon character with a blue and yellow outfit 62
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a butterfly with a flag on it's wings 37
# a drawing of a green and red pokemon 36
# a very cute looking green pokemon with big eyes 47
# a cartoon character with a weird look on his face 49
# a yellow and black butterfly on a white background 50
# a purple cartoon character with a yellow ear 44
# a cartoon bat with its mouth wide open 38
# a cartoon character with a sword in his hand 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of an animal with wings and a tail 44
# a red and black cartoon character holding a sword 49
# a pink butterfly with black wings and a white background 56
# a bird with a long beak flying through the air 46
# a blue and white bird with a long tail 38
# a cartoon bird with a red and yellow striped shirt 50
# a drawing of a pokemon with a flower on top of it 49
# a black and white cartoon character with big eyes 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a very cute looking animal with horns on it's head 50
# a cartoon character flying through the air 42
# a cartoon character with a star on his head 43
# a cartoon character with a backpack on his back 47
# a drawing of a gray and black dragon 36
# a red and white pokemon with yellow spikes 42
# a couple of pokemon standing next to each other 47
# a stylized image of a blue and brown robot 42
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character in a striped outfit 52
# a drawing of a bird flying through the air 42
# a very cute looking pokemon with big eyes 41
# a pink bird with orange eyes and a pink tail 44
# a drawing of a blue and yellow dragon 37
# a drawing of a cat with its arms in the air 43
# a drawing of a cat with a wheel in his hand 43
# a drawing of a cartoon character holding two green balls 56
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a white and red dragon 35
# a green and brown butterfly on a white background 49
# a cartoon character with a big nose and a big nose 50
# a drawing of a pokemon stuffed animal 37
# a drawing of a creature with two green leaves 45
# a drawing of a cartoon character flying through the air 55
# a drawing of a pokemon with a blue hat 38
# a drawing of a yellow and gray pokemon character 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon picture of a green vegetable with eyes 48
# a drawing of a blue dragon with red eyes 40
# a drawing of a cartoon character holding a surfboard 52
# a small bird with a black and white tail 40
# a drawing of a blue pokemon laying down 39
# a cartoon butterfly with a sad look on its face 47
# a drawing of a blue and black pokemon 37
# a drawing of a green bird with a knife in its mouth 51
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a yellow and black pokemon pokemon character 44
# a drawing of a dog holding a stick 34
# a cartoon character with two eyes and a mouth open 50
# a cartoon character with a toothbrush in his mouth 50
# a drawing of a green plant with a yellow face 45
# a drawing of a blue and silver pokemon 38
# a cartoon bird with a green hat on its head 43
# a very cute looking animal with big eyes 40
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of an angry looking animal with red and purple stripes 64
# a drawing of a dragon sitting on its hind legs 46
# a cartoon animal with a pink ball on its head 45
# a blue and purple dragon with a black mouth 43
# a close up of a cartoon character on a white background 55
# a blue and yellow dragon flying through the air 47
# a colorful bird with a black beak and a red beak 48
# a drawing of a cartoon character with arms and legs 51
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a volcano with a bird on top of it 47
# a drawing of a pink pokemon pokemon character 45
# a mushroom with a pink nose and a brown cap 43
# a blue bird sitting on top of a cloud 37
# a drawing of a purple creature with a big smile on it's face 60
# a drawing of a group of cartoon characters 42
# a drawing of a cartoon character with a hat on 46
# a cartoon fish with a big smile on it's face 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a red and black dragon 35
# a cartoon character with a big smile on his face 48
# a blue and white whale floating on top of a body of water 57
# a very cute looking pokemon character 37
# a drawing of a blue and orange pokemon 38
# a pink and white cartoon animal with a yellow tail 50
# a drawing of a very cute looking caterpillar 44
# a cartoon of a fire breathing dragon 36
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue stuffed animal sitting on top of a white surface 55
# a drawing of a dragon with black and white spots 48
# a very cute looking cartoon character with big eyes 51
# a drawing of a dinosaur in a dress 34
# a black and white bird with a red beak 38
# a drawing of a cartoon character with wings 43
# a blue jellyfish with red eyes and a red nose 45
# a blue sea horse with a yellow tail 35
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a very cute looking animal with big eyes 40
# a drawing of a blue and yellow pokemon 38
# a blue and yellow cartoon character with its mouth open 55
# a drawing of a pokemon pokemon character 40
# a drawing of a yellow pokemon sitting on the ground 51
# a drawing of a cartoon seal with its mouth open 47
# a cartoon character with a big smile on his face 48
# a drawing of a cartoon character with big eyes 46
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character holding a giant pink donut 46
# a cartoon butterfly with blue eyes and yellow wings 51
# a drawing of a pink bird flying through the air 47
# a drawing of a small animal with orange and gray colors 55
# a drawing of a turtle holding a roll of toilet paper 52
# a drawing of a pair of owls with pink wings 43
# a drawing of a pokemon pokemon with its mouth open 50
# a cartoon character with a hat on his head 42
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a picture of a pokemon with a leaf on its back 46
# a green bird with a red tail and a black nose 45
# a cartoon character with red eyes and arms 42
# a purple and blue dragon flying through the air 47
# a very cute looking cartoon character with big eyes 51
# a green cartoon character with a leaf on its head 49
# a very cute looking pokemon with big eyes 41
# a drawing of a blue and white pokemon 37
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a brown and white animal with a big nose 40
# a blue and white bird with its wings spread 43
# a pink cat with brown ears sitting down 39
# a drawing of a cartoon character in a red and blue outfit 57
# a white bear with a blue ribbon around its neck 47
# a drawing of a deer standing under a tree 41
# a cartoon character flying through the air 42
# a drawing of a white pokemon with wings 39
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a blue and a brown monster 39
# a colorful bird is standing on its hind legs 44
# a cartoon picture of a giant turtle with its mouth open 55
# a blue and black object with two eyes 37
# a cartoon rabbit with a scarf around its neck 45
# a drawing of a cartoon character in a yellow outfit 51
# a white ghost floating in the air 33
# a cartoon monkey flying with a bone in its mouth 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a green and yellow cartoon character 36
# a pink and brown animal sitting on top of a white surface 57
# a cartoon of a purple sea creature with its mouth open 54
# a paper model of a blue object 30
# a cartoon ball with a smile on it's face 40
# a drawing of a red creature with yellow eyes 44
# a drawing of a pink cartoon character 37
# a black and white animal with pink eyes 39
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a pokemon type pokemon type pokemon type pokemon type pokemon type pokemon type 92
# a blue and white cartoon character with horns 45
# a drawing of a girl with a boxing glove 39
# a cartoon of a crescent moon with a pink eye 44
# a drawing of a pokemon with a green leaf on it's back 53
# a blue and white cube is shown in the shape of a cube 53
# a picture of a cartoon character with horns 43
# a cartoon character with a pink and white outfit 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon cow laying on its back on the ground 46
# a drawing of a fire breathing dragon 36
# an image of a cartoon character with a big smile 48
# a cartoon character with a strange look on his face 51
# a very cute looking animal with a helmet on 43
# a cartoon character holding a large piece of wood 49
# a picture of a butterfly that is orange and green 49
# a black and white cat with blue eyes 36
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a picture of a cartoon character in a hole 42
# a drawing of a cartoon character with blue hair 47
# a cartoon character with a potted plant on his head 51
# a pink dog with its mouth open and tongue out 45
# a drawing of a woman standing next to a giant animal 52
# a cartoon turtle sitting on top of a red ball 45
# a cartoon character with three green balls on his head 54
# a drawing of a pumpkin with a bird on top of it 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a blue and red dragon 34
# a drawing of a pokemon with blue eyes 37
# a very cute looking pokemon with big eyes 41
# a red cartoon character laying on the ground 44
# a drawing of a creature with a big smile on its face 52
# a cartoon monkey with a blue mask on 36
# a cartoon character flying through the air 42
# a pink object with a green leaf on top of it 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character with blonde hair 49
# a cartoon bird with a scarf around its neck 43
# a cartoon character holding onto a pole 39
# a drawing of a little girl with a flower in her hair 52
# a picture of a cartoon character with a sword 45
# a drawing of a blue and white fish 34
# a cartoon cat is holding onto a leash 37
# a red and black dragon standing in front of a white background 62
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a yellow and black pokemon 39
# a drawing of a red and yellow bird holding a stick 50
# a drawing of a cat with a flower on its back 44
# a red and blue dragon with its mouth open 41
# a yellow and black tie and a purple and white tie 49
# a drawing of a cartoon character on a cloud 43
# a cartoon character is holding a banana 39
# a drawing of a cartoon character with big eyes 46
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a green butterfly with red and black wings 42
# a drawing of a cat with red eyes 32
# a close up of a cartoon character with big eyes 47
# a cartoon mouse with a pink shirt and tie 41
# a cartoon picture of a small furry animal 41
# a very cute looking pokemon with a big hat on 45
# a very cute looking animal with big ears 40
# a drawing of a red and white pokemon 36
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon dog is standing in a pose 35
# a drawing of a cartoon character with a sword 45
# a pink and blue bird with big eyes 34
# a drawing of a blue and white robot 35
# a blue bird with yellow feet and a yellow beak 46
# a drawing of a red and black robot with wings 45
# a colorful butterfly is shown on a white background 51
# a drawing of a flower with green leaves 39
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a bison with horns and horns 41
# a purple butterfly with orange and pink stripes 47
# a cartoon character with a pink and blue tail 45
# a purple ball with a skull and cross bones on it 48
# a blue and black cartoon character with big eyes 48
# a drawing of a pokemon with a hat on top of it 46
# a cartoon sheep is kicking a soccer ball 40
# a red and black dragon with a red crown on it's head 52
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a very cute looking cartoon character with big eyes 51
# a very cute looking pokemon character in a costume 50
# a yellow and brown pokemon pokemon character flying through the air 67
# a cartoon bird with a big smile on its face 43
# an image of a cartoon character flying through the air 54
# a pink cartoon character with a blue tail 41
# a drawing of a blue and purple animal 37
# a drawing of a person on a ball with wings 42
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon green fish with a big smile on it's face 50
# an orange and green robot with a smile on it's face 51
# a purple cartoon character pointing at something 48
# a drawing of a yellow and red pokemon 37
# a green and yellow animal with a yellow bow on its head 55
# a drawing of a shark with its mouth open 40
# a cartoon character flying through the air 42
# a cartoon character with a big smile on his face 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a pink and white cartoon character with blue eyes 49
# a cartoon porcupine running with its mouth open 47
# a cartoon blue bird with its mouth open 39
# a green and white cloud with two orange eyes 44
# a drawing of a pink and black pokemon character 47
# a blue and white bird flying through the air 44
# a drawing of a deer with flowers on its antlers 47
# a white cloud with pink eyes and a pink nose 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a red and yellow insect 36
# a cartoon picture of a blue and white pokemon 45
# a very cute looking pokemon character with big ears 51
# a blue and white cartoon character with a big smile 51
# a blue bird with a red and white beak 37
# a drawing of a cat sitting on top of a flower 45
# a gray and black cat with yellow eyes 37
# a pink and yellow deer with a yellow bow on its head 52
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# an emote emote emote emote emote emote emote em 47
# a bird with a scarf around its neck 35
# a cartoon of a blue and red dragon 34
# a drawing of a blue and black pokemon 37
# a drawing of a pink bird with black eyes 40
# a drawing of a bug with a re 28
# a drawing of a pink and blue pokemon 36
# a drawing of a white and black cat with blue eyes 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a green turtle with a yellow flower on its head 47
# a drawing of a small animal with green leaves 45
# a cartoon pikachu with a big smile on his face 46
# a drawing of a bird with blue eyes 34
# a cartoon pig with a pink tail and a pink tail 46
# an origami dog with a pink and blue body 40
# a very cute looking cartoon character with a big smile 54
# a picture of a pink monster with green eyes 43
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a red and yellow pokemon pokemon character 42
# a drawing of a black and gray dragon 36
# a cartoon character with a pink nose sitting in a pile of rocks 63
# a cartoon elephant with a sad look on its face 46
# a cartoon character sitting on top of a green leaf 50
# a cartoon character with a toothbrush in his mouth 50
# a cartoon character with pink hair and a pom pom on top of it 61
# a drawing of a robot holding a baseball bat 43
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a purple bird with a yellow cross on it's head 46
# a very cute looking animal with big ears 40
# a drawing of a cartoon character with horns and horns 53
# a brown and black animal with a white background 48
# a drawing of a bird flying over a crescent 42
# a cartoon character floating on top of a blue object 52
# a drawing of a blue and white pokemon 37
# a blue object with two yellow eyes 34
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon panda with a leaf in its mouth 40
# a cartoon picture of a crab wearing a hat 41
# a drawing of a pokemon type pokemon type pokemon type pokemon type pokemon type pokemon type 92
# a cartoon character with big eyes and a big nose 48
# a blue and black animal with a hat on it's head 47
# a drawing of an animal with blue eyes 37
# a blue spider with a yellow hat on it's head 44
# a blue bell with red eyes on a white background 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon elephant with a star on its back 42
# a brown and white animal with a black nose 42
# a pink and yellow animal holding a pink balloon 47
# a couple of gears sitting next to each other 44
# a drawing of a yellow and black bee 35
# a colorful bird flying through the air 38
# a very cute looking pokemon with big wings 42
# a yellow bee with two eyes and two antennae 43
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a purple dragon with spikes on it's head 53
# a cartoon character with a star hat on 38
# a drawing of a fox with a red tail 34
# a white and blue pokemon character with its mouth open 54
# a drawing of a purple and white animal 38
# a drawing of a flying object with green eyes 44
# a yellow and black insect with large wings 42
# a picture of a cartoon character with two arrows 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character with a smile on his face 44
# a cartoon character sleeping on top of a ball 45
# a blue butterfly with white stripes on its wings 48
# a drawing of a pink cat flying through the air 46
# a green and white stuffed animal wearing a green hat 52
# a bird with a large beak and a large beak 41
# a drawing of a horned animal with horns 39
# a picture of a mushroom with pink eyes 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a white and black cat mask with blue eyes 41
# a green and yellow bird with big eyes 37
# a drawing of an animal with a long tail 39
# a drawing of a person with a hat on 35
# a cartoon character with a hat and glasses 42
# a cartoon character with a sword in his hand 44
# a yellow and blue toy flying through the air 44
# a drawing of a plant with a face on it 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a pink butterfly with a black and white stripe on it's wings 60
# a cartoon of two birds standing next to each other 50
# a drawing of a ball with spikes on it 37
# a blue cartoon character with its mouth open 44
# a cartoon character is holding a baseball bat 45
# a drawing of a cartoon character laying on the ground 53
# a very cute looking cartoon character with big eyes 51
# a drawing of a cartoon character with two eyes 46
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character with blue hair 47
# a drawing of a cartoon character holding a flame 48
# a cartoon of a pikachu flying through the air 45
# a drawing of a purple monster with big eyes 43
# a gray and yellow dragon with large horns 41
# a green and yellow spider with its tongue out 45
# a drawing of a pink cat with big blue eyes 42
# a drawing of a shark with its mouth open 40
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a furry white dog with red eyes 44
# a very cute looking cartoon character with big eyes 51
# a drawing of a very cute looking pokemon 40
# a drawing of a cat with red hair and blue eyes 46
# a blue and black bat with black wings 37
# a cartoon character flying through the air 42
# a cartoon character flying through the air 42
# a cartoon bird with an angry look on its face 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a white and purple pokemon 39
# a drawing of a blue and yellow dragon 37
# a drawing of a blue and yellow pokemon 38
# a green and white pokemon with leaves on its back 49
# a drawing of a red and yellow dragon 36
# a cartoon bear with a ring around its neck 42
# a close up of a metal object on a white background 50
# a blue and white snake with horns on its head 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a white ball with red glasses on top of it 42
# a cartoon character with a mushroom on his head 47
# a very cute looking bird with big wings 39
# a cartoon bird with multicolored wings and a black beak 55
# a very cute looking bird with big wings 39
# a cartoon picture of a stone dragon 35
# a cartoon bird with a bandanna on its head 42
# a blue and orange cartoon character holding a stuffed animal 60
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character in a karate outfit 38
# a very cute looking cartoon character with big eyes 51
# a close up of a very cute looking pokemon 41
# a drawing of a purple eggplant with a green leaf 48
# a cartoon bird sitting on top of a white surface 48
# a cartoon picture of a giant rock with eyes 43
# a red bird with black wings flying through the air 50
# a blue and yellow shark with its mouth open 43
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a group of three brown rocks sitting on top of a pile of dirt 61
# a drawing of a blue and green dinosaur with a pink flower on its back 69
# a drawing of a purple and white pokemon 39
# a drawing of a blue pokemon pokemon character 45
# a ball with a blue cap on top of it 35
# a drawing of a blue dinosaur with wings 39
# a drawing of an orange and blue creature 40
# a red and white cartoon character with big eyes 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a very cute looking cartoon character with big eyes 51
# a drawing of a white ball with spikes on it 43
# a blue and white cartoon character with big eyes 48
# a black and white fish with pink eyes 37
# a cartoon of a deer with a tree on its back 43
# a drawing of a pink ball with a flower on it 44
# a green insect with two green eyes 34
# a white and green pokemon pokemon character 43
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character with a big smile 49
# a drawing of a black and white cat 34
# a yellow and black pokemon pikachu with pink eyes 49
# a drawing of a small dog with big eyes 38
# a yellow and black cartoon character with a big smile 53
# a picture of a blue bird with white wings 41
# a drawing of a blue dragon with yellow eyes 43
# a drawing of a yellow creature with a black nose 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a very cute looking pokemon character with big eyes 51
# a picture of a fish with a red eye 34
# a drawing of a bird with a long tail 36
# a blue and white cartoon dog with a hat on 42
# a gray and white object with a red light 40
# a drawing of a dragon with its mouth open 41
# a drawing of a woman in a red cape 34
# a cartoon character with a big smile on his face 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon bird with a hat on its head 37
# a very cute looking pokemon with big eyes 41
# a drawing of a blue and red dragon 34
# a very cute looking animal with a big nose 42
# a drawing of an owl with a crown on its head 44
# a green and orange cartoon character 36
# a red and white paper model of a dragon 39
# a very cute looking cartoon character with big eyes 51
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cat with a pink tail 35
# a pink and green cartoon character with large eyes 50
# a drawing of a blue and red pokemon character 45
# an image of a cartoon character flying through the air 54
# a green and orange insect with large eyes 41
# a red and black butterfly sitting on top of a white background 62
# a drawing of a red and black furry animal 41
# a pink and a blue pokemon sitting next to each other 52
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a green and black dragon 37
# a cartoon character with an evil look on his face 49
# a cartoon character with a crown on his head 44
# a drawing of a cartoon character holding a tennis racket 56
# a very cute looking animal with big eyes 40
# a paper model of a tortoise shell 33
# a drawing of a pokemon character with re 40
# a very cute looking cartoon character with big horns 52
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue and white cartoon character with red eyes 48
# a drawing of a cartoon dinosaur with its mouth open 51
# a red and white bird with a yellow beak 39
# a cartoon picture of a devil with horns and legs 48
# a drawing of a purple and green pokemon 39
# a colorful butterfly that is on a white background 50
# a cartoon giraffe sitting down with its eyes wide open 54
# a picture of a butterfly with blue and black wings 50
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a bird flying through the air 42
# a cartoon bird with a hat on its head 37
# a blue robot with a cross on it's chest 39
# a drawing of a cartoon character with two arms in the air 57
# a drawing of a bird with two wings 34
# a very cute looking pokemon with a big beak 43
# a picture of a butterfly made out of paper 42
# a drawing of a green and yellow dragon 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a couple of gears with eyes on them 35
# a red and yellow insect flying through the air 46
# a drawing of a robot like creature with blue eyes 49
# a blue and yellow dragon with its mouth open 44
# a drawing of a blue bird with a yellow crown on its head 56
# a cartoon character with a pink nose and purple hair 52
# a cartoon of a blue and black dragon 36
# a yellow and white pokemon pokemon character 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon of a red monster with a flame coming out of it's mouth 64
# a drawing of a white and red pokemon 36
# a drawing of a spider on a white background 43
# a drawing of a pikachu with blue eyes 37
# a black and white picture of a cat wearing a witches hat 56
# a drawing of a white and blue pokemon 37
# a drawing of a red and yellow pokemon 37
# a pink cartoon character with big eyes 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a star with a red eye 34
# a drawing of a deer with antlers on it's head 45
# a picture of a yellow butterfly on a white background 53
# a cartoon of a man with his arms in the air 43
# a blue bird flying through the air with clouds 46
# a very cute looking bird with big wings 39
# a cartoon character in grey and yellow 38
# a drawing of a blue and yellow pokemon 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon bird with a hat on its head 37
# a gray and white pokemon ball with blue eyes 44
# a very cute looking pokemon with a big smile 44
# a cartoon of a pikachu with a leaf on its head 46
# a yellow and black cartoon character with big ears 50
# a purple and black animal with big eyes 39
# a cartoon character flying through the air 42
# a pink pokemon ball with a green leaf on top of it 50
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a purple bird with a white cloud on its head 44
# a drawing of a cat sitting on top of a ball 43
# a bird with its mouth open sitting on a piece of paper 54
# a cartoon character with a purple hat and purple hair 53
# a cartoon of a pink creature with yellow eyes 45
# a drawing of a cartoon character with eyes and a nose 53
# a drawing of a cat with a hat on it's head 42
# a blue and white cartoon character with a crown on his head 59
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon monkey with two hands up in the air 45
# a robot with a yellow helmet and green legs 43
# a blue and green bird with a yellow tail 40
# a drawing of a cartoon character with long legs 47
# a drawing of a cartoon character holding a knife 48
# a cartoon elephant with a red nose and orange ears 50
# a drawing of a green and yellow dragon 38
# a black and white zebra standing next to a star 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a picture of a unicorn with orange hair 39
# a green and red insect flying through the air 45
# a black and white poodle with a heart on its tail 49
# a cartoon character flying through the air 42
# a very cute looking pokemon with big eyes 41
# a drawing of a deer with a bow on its head 42
# a cartoon of a blue creature with pink feet 43
# a drawing of a pink and blue pokemon 36
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon bird with a surprised look on its face 61
# a white bird with a red beak is in the air 42
# a drawing of a cartoon character in a pink outfit 49
# a cartoon character with a hat on top of his head 49
# a cartoon picture of a cat with a helmet on 43
# a blue and yellow pokemon character with its mouth open 55
# a drawing of a pony with red hair 33
# a picture of a white horse with orange and yellow flames 56
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character wearing a green hat 52
# a picture of a cartoon character with spoons and spoons 55
# a drawing of a pink fish with blue eyes 39
# a cartoon character is holding a large object 45
# a cartoon of a green tree with leaves 37
# a drawing of a red and black pokemon 36
# a very cute looking pokemon character with big eyes 51
# a green stuffed animal with a crown on its head 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon of a red and white dragon 35
# a red and white ball with an angry look on its face 51
# a cartoon character is holding a large object 45
# a picture of a cartoon character in a costume 45
# a drawing of a pink pokemon ball floating in the air 52
# a blue and white cartoon character running 42
# a blue bird flying through the sky with clouds 46
# a yellow and orange object with large spikes 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue cartoon character sitting on the ground 46
# a cartoon character with a target in his mouth 46
# a drawing of a cartoon character in pink and grey 49
# a blue and white fish with red accents 38
# a drawing of a cartoon character flying through the air 55
# a yellow and white cartoon character with a red eye 51
# a blue bird with a yellow beak on it's head 43
# an image of a cartoon character flying through the air 54
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character with green eyes 48
# a colorful bird flying through the air 38
# a drawing of a woman in a pink dress 36
# a cartoon character with a cross on it's chest 46
# a cartoon character sitting in the middle of a pose 51
# a cartoon character with an angry look on his face 50
# a white object with a yellow line on it 39
# a cartoon character with a magnifying glass 43
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a blue and brown turtle 36
# a drawing of a gray and white pokemon 37
# a pikachu flying with an arrow in its hand 42
# a drawing of a pokemon with its mouth open 42
# a drawing of a cartoon character with wings 43
# a cartoon bird with a green leaf around its neck 48
# a pink and yellow cartoon character holding a banana 52
# a drawing of a shark with a fish in it's mouth 46
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon bird with a re 24
# a cartoon bunny holding a piece of cheese 41
# a drawing of a white and black pokemon 38
# a cartoon character with a smile on his face 44
# a drawing of a bird flying through the air 42
# a cartoon character with a big smile on his face 48
# a drawing of a white and black animal with blue eyes 52
# a cartoon of a flying bat with a heart on it's chest 52
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue cartoon character holding a star 39
# a black and white photo of a butterfly 38
# a very cute looking cartoon character with big eyes 51
# a cartoon character with a bat on his back 42
# a drawing of a fish with a long tongue 38
# a picture of a cartoon character on a cell phone 48
# a cartoon character with a cat like body 40
# a drawing of a cartoon character holding a flower 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character in blue and black 50
# a drawing of a fish with a horn on it's head 44
# a very cute looking pokemon with big wings 42
# a drawing of a gray and white animal 36
# an image of a cartoon character in a blue outfit 48
# a blue and white pokemon type pokemon type pokemon type pokemon type pokemon type pokemon type 94
# a drawing of a black cat with yellow and pink wings 51
# a drawing of a gray and white dragon 36
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a brown teddy bear holding a white object 41
# a drawing of a black and white cat with green eyes 50
# a drawing of a cartoon character wearing sunglasses 51
# a blue and orange fish with its mouth open 42
# a blue butterfly with white dots on it's wings 46
# a blue and yellow butterfly with yellow stripes 47
# a drawing of a cat with blue eyes 33
# a drawing of a cartoon character holding a wrench 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a bird with a hat on its head 42
# a drawing of a star with a jewel in the center 46
# a yellow bird flying through the air 36
# a drawing of a bird with its mouth open 39
# a blue butterfly with white dots on its wings 45
# a fish with a horn on it's head 31
# a cartoon character with a tongue sticking out 46
# a drawing of a cartoon character holding a large object 55
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a green and white pokemon 38
# a drawing of a blue fish with yellow eyes 41
# a white pokemon with a red and blue tail 40
# a very cute looking pokemon type pokemon type pokemon type pokemon type pokemon type pokemon type 97
# a drawing of a yellow and white pikachu 39
# a green and white cartoon character with a sword 48
# a green and yellow pokemon character 36
# a cartoon character with a red ball in his hand 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a white and blue bird with a yellow beak 40
# a very cute looking cartoon character with big eyes 51
# a drawing of a bird flying through the air 42
# a drawing of a cartoon character with his hands on his hips 59
# a pink and black cartoon character flying through the air 57
# a drawing of a purple cat with its mouth open 45
# a cartoon bison with horns and horns on it's head 49
# a drawing of a dragon with its mouth open 41
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a yellow and red butterfly on a white background 48
# a very cute looking cartoon character with big eyes 51
# a picture of a pink and yellow pokemon figure 45
# a cartoon character with a leaf on his head 43
# a blue and yellow bird with long wings 38
# a drawing of a purple and white pokemon 39
# a cartoon character with blue hair and a blue hat 49
# a cartoon character with green eyes and a hat 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a red cartoon character is flying through the air 49
# a candle with a blue flame on top of it 39
# a drawing of a cartoon character with long hair 47
# a blue pokemon character with yellow eyes and a white shirt 59
# a drawing of a black cat with a yellow star 43
# a red and blue toy flying through the air 41
# a green cartoon character with a sad look 41
# a cartoon character with a big smile on his face 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a small animal with a pink nose 44
# a drawing of a cartoon character with a green hat 49
# a blue and white cartoon character flying through the air 57
# a black and white dog with red eyes 35
# a cartoon elephant with a backpack on it's back 47
# a bird with yellow eyes and a black beak 40
# a cartoon character with a broken arm 37
# a picture of a cartoon character with a hat on 46
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a very cute looking pokemon character with big eyes 51
# a drawing of a green and red dragon 35
# a cartoon bee with a big smile on it's face 43
# a drawing of a sheep with a bell on its head 44
# a cartoon pikachu with big eyes and big ears 44
# a drawing of a white and blue pokemon 37
# a cartoon character with a green leaf on his head 49
# a picture of a cartoon character with blue and yellow hair 58
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character sitting on top of a blue ball 49
# a drawing of a very cute looking pokemon 40
# a drawing of a pokemon with a big smile 39
# a drawing of a green pokemon with red eyes 42
# a cartoon bird with a hat on its head 37
# a drawing of a green cat with a white dress 43
# a drawing of a blue and yellow pokemon 38
# a cartoon picture of a pink and gray dinosaur 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a green and black bird with spots on it's wings 47
# a drawing of a cartoon character with claws 43
# a drawing of a woman in a white dress 37
# a cartoon character sitting on the ground with a cell phone in his hand 71
# a yellow and pink pokemon pikachu with big eyes 47
# a green and yellow cartoon character with big eyes 50
# a cartoon character flying through the air 42
# a drawing of an octopus with a sad face 39
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a black and yellow pokemon type animal 38
# a blue bird with a big smile on it's face 41
# a purple snake sitting on top of a white background 51
# a cartoon character with a green leaf on top of it 50
# a very cute looking animal with a big nose 42
# a couple of cartoon style items on a white background 53
# a drawing of a spider with big eyes 35
# a green and brown animal with a tree on top of it 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character holding onto a ring 39
# a drawing of a cat with green eyes 34
# a pokemon ball with a bird on top of it 39
# a drawing of a cartoon character doing a kick 45
# a drawing of a purple and green dragon 38
# a drawing of a black and white animal with horns 48
# a drawing of a purple and yellow flower 39
# a drawing of a green creature with a long tail 46
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character with a sword 45
# a cartoon turtle with a helmet on its head 42
# a yellow and black cartoon character is flying 46
# a blue and white cartoon character holding a target 51
# a drawing of a cartoon character with big eyes 46
# a blue and white pokemon pokemon character 42
# a cartoon turtle with a tree on its back 40
# a pink and black bird with a pink tail 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a yellow and green animal with its mouth open 45
# a drawing of a chamelon with a crown on it's head 49
# a very cute looking purple pokemon character 44
# a drawing of a blue and white cat with big eyes 47
# a drawing of a black and white poodle 37
# a cartoon character with a sad look on his face 47
# a pink and black cartoon character flying through the air 57
# a cartoon rat with its mouth open and it's mouth wide open 58
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a reindeer with antlers on it's head 49
# a drawing of a fox with wings on it's back 42
# a cartoon of a horned animal with a green scarf around its neck 63
# a drawing of a pikachu in the air 33
# a cartoon character flying through the air 42
# a cartoon character with a fork and spoon in his hand 53
# a very cute looking pokemon pikachu with big eyes 49
# a drawing of a pumpkin with a bird on top of it 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue and yellow animal with horns on it's head 48
# a cartoon character flying through the air 42
# an orange and blue cartoon character with big eyes 50
# a red fish with a gold crown on its head 40
# a cartoon character with a strange hair style 45
# a cartoon character with a fire on his back 43
# a cartoon picture of a tortoise with a cloud on its back 56
# a picture of a pink and white animal with blue eyes 51
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a very cute looking animal with horns on it's head 50
# a cartoon picture of a giant spider crawling out of a rock 58
# a cartoon character with a scarf around his neck 48
# a drawing of a blue dragon with red eyes 40
# a blue cartoon character with a target in his hand 50
# a drawing of an airplane flying in the sky 42
# a drawing of a furry animal wearing a vest 42
# a cartoon picture of a bear holding a baseball bat 50
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a person with a hat on 35
# a drawing of a pokemon pikachu in a bowl 40
# a cartoon animal with a big smile on its face 45
# a yellow and blue butterfly sitting on top of a white surface 61
# a white and purple cartoon character with green eyes 52
# a cartoon of a pink and purple object 37
# a blue and black chandelier with flames coming out of it 56
# an image of a cartoon character in a shell 42
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon picture of a blue and white pokemon 45
# a drawing of a cartoon character with blue eyes 47
# a drawing of a cat wearing a purple hat 39
# a drawing of a bird with large eyes 35
# a black and white animal with a lightning bolt on its head 58
# a drawing of a blue and white object floating in water 54
# a drawing of a blue and yellow dragon 37
# a pink and white cartoon character with wings 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a furry animal sitting down 40
# a cartoon pikachu with a pink dress and a pink bow 50
# a drawing of a cartoon character with a boxing glove 52
# a purple elephant with a yellow tusk 36
# a drawing of a yellow and green pokemon 39
# a cartoon character with a flower on his head 45
# a drawing of a cat with a star on its tail 42
# a drawing of a lizard with a flower on its head 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a purple and green bird with a long tail 40
# a blue and white bird with a red beak 37
# a drawing of a green and black pokemon 38
# a drawing of a blue and red pokemon 35
# a green pokemon sitting on top of a leaf 40
# a drawing of a deer with colorful feathers on it's head 55
# a very cute looking pokemon sitting on top of a rock 52
# a pink animal laying on top of a white floor 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a dragon with its mouth open 41
# a cartoon character is sitting on a flower 42
# a drawing of a woman in a pink dress with a dragon head 55
# a white and red stuffed animal with black eyes 46
# a drawing of a flower with a bird on it 39
# a yellow and black bee with a white background 46
# a drawing of a blue sea turtle holding a rock 45
# a drawing of a purple butterfly with big eyes 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a pony with a blue tail 36
# a drawing of a woman in a green and white dress 47
# a drawing of a green pokemon with red eyes 42
# a drawing of a fish with a blue and yellow face 47
# a drawing of a woman standing on top of a rock 46
# a green and purple cartoon character with wings 47
# a drawing of a cartoon character flying through the air 55
# a cartoon picture of a blue pokemon with a pink flower on its head 66
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a dragon with a green and white tail 49
# a drawing of a cat with big eyes 32
# a cartoon bird with a green leaf on its head 44
# a drawing of a pink cat with blue eyes 38
# a cartoon character with a yellow shirt and blue pants 54
# a drawing of a green and white bird 35
# a cartoon blue fish with a yellow fin 37
# a blue cartoon character with a red nose and ears 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character with a big smile on his face 61
# a cartoon picture of a cat with its head in the air 51
# a green and yellow snake with a smile on its face 49
# a drawing of a toothbrush with a yellow top 43
# a green bird with a hat on its head 35
# a black and white bird with blue wings 38
# a blue bird with a pink beak and a black nose 45
# a drawing of a cartoon character flying through the air 55
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue and orange cartoon fish with its mouth open 50
# a pink and white animal sitting on top of a white surface 57
# a cartoon giraffe with a ball in its mouth 42
# a drawing of a cartoon character in purple and white 52
# a drawing of a gray and yellow pokemon 38
# a drawing of a cartoon character with a pink nose 49
# a drawing of a cartoon character holding a gun 46
# a drawing of a purple and white animal 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blueberry with a green leaf on it's head 42
# a yellow and black pokemon with big blue eyes 45
# an image of an animal with big eyes 35
# a blue and white cartoon character running 42
# a cartoon character with a lightning bolt 41
# a drawing of a pikachu with a green leaf on its head 52
# a cartoon character with a black cat on it's back 49
# a very cute looking pokemon character with a fire on it's face 62
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cat with yellow and purple markings 50
# a drawing of a cat wearing a helmet 35
# a drawing of a bird with a pink ribbon around its neck 54
# a drawing of a cartoon character with a green hat 49
# a drawing of a green creature with its mouth open 49
# a cartoon animal with a red mohawk on its head 46
# a brown and black animal with big eyes 38
# a bird with an arrow in its beak 32
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon bunny flying through the air 38
# a cartoon of a black and white pokemon 38
# a drawing of a cat that is smiling 34
# a drawing of a cartoon character flying through the air 55
# a cartoon bird with a pink beak and a green tail 48
# a drawing of a white rabbit holding a piece of paper 52
# a pink bird sitting on top of a white surface 45
# a blue and white stuffed animal sitting on top of a white surface 65
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue and white bird with a yellow beak 40
# Shape before linear layer: torch.Size([1, 3, 256, 256])
# ----------
# Epoch: 0
# Loss: 734.2800788879395
# Accuracy: 0.4801920768307323 % (4 / 833)
# a cartoon character with a strange look on his face 51
# a cartoon character with a crown on his head 44
# a drawing of a cat sitting on top of a flower 45
# a drawing of a purple and white pokemon 39
# a very cute looking bird with big wings 39
# a drawing of a blue and orange pokemon 38
# a drawing of a black and gray dragon 36
# a drawing of a red creature with yellow eyes 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a blue bird with a yellow crown on its head 56
# a colorful bird flying through the air 38
# a very cute looking animal with big eyes 40
# a picture of a mushroom with pink eyes 38
# a cartoon of a man with his arms in the air 43
# a gray and black cat with yellow eyes 37
# a cartoon monkey with two hands up in the air 45
# a picture of a cartoon character in a costume 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a black and white dog with red eyes 35
# a drawing of a cartoon character in a red and blue outfit 57
# a pink butterfly with a black and white stripe on it's wings 60
# a yellow and green animal with its mouth open 45
# an image of a cartoon character in a blue outfit 48
# a blue and yellow pokemon character with its mouth open 55
# a couple of gears sitting next to each other 44
# a drawing of a cartoon character holding a large object 55
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character on a cloud 43
# ...
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a red and yellow pokemon character 47
# a drawing of a cartoon character with two eyes 46
# a purple butterfly with orange and pink stripes 47
# a very cute looking purple pokemon character 44
# a blue and white fish with red accents 38
# a drawing of a dragon with its mouth open 41
# a cartoon character with an evil look on his face 49
# a drawing of a yellow and black bee 35
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# an orange and blue cartoon character with big eyes 50
# a drawing of a cartoon character with claws 43
# a drawing of a cartoon character in purple and white 52
# a drawing of a cartoon character with blue hair 47
# a brown and black animal with a white background 48
# a black and white fish with pink eyes 37
# a picture of a cartoon character with blue and yellow hair 58
# a green and yellow toy with a red nose 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character with a big smile on his face 48
# an origami dog with a pink and blue body 40
# a drawing of a white and black animal with blue eyes 52
# a drawing of a white and black cat with blue eyes 49
# a drawing of a white and blue pokemon 37
# a drawing of a pumpkin with a bird on top of it 47
# a cartoon turtle with a helmet on its head 42
# a picture of a butterfly that is orange and green 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cat with big eyes 32
# Shape before linear layer: torch.Size([1, 3, 256, 256])
# ----------
# Epoch: 5
# Loss: 580.3736310005188
# Accuracy: 16.566626650660265 % (138 / 833)
# a drawing of a cartoon character holding a tennis racket 56
# a picture of a cartoon character with two arrows 48
# a blue and white whale floating on top of a body of water 57
# a pink cat with brown ears sitting down 39
# a drawing of a cartoon character flying through the air 55
# a cartoon character flying through the air 42
# a drawing of a lizard with a flower on its head 47
# a drawing of a white and red dragon 35
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character with a pink and white outfit 48
# a drawing of a dragon with its mouth open 41
# a drawing of a cartoon character flying through the air 55
# a drawing of a purple cat with its mouth open 45
# a cartoon of a pink creature with yellow eyes 45
# a cartoon picture of a blue and white pokemon 45
# a cartoon character with a strange look on his face 51
# a drawing of an animal with a long tail 39
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a white and blue bird with a yellow beak 40
# a drawing of a sheep with a bell on its head 44
# an orange and blue cartoon character with big eyes 50
# a cartoon green fish with a big smile on it's face 50
# a pink and yellow animal holding a pink balloon 47
# a very cute looking pokemon with a big beak 43
# a blue and white cartoon character with a big smile 51
# a cartoon panda with a leaf in its mouth 40
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character flying through the air 42
# a purple ball with a skull and cross bones on it 48
# a drawing of a yellow and red pokemon 37
# a drawing of a cat with a hat on it's head 42
# a very cute looking cartoon character with a big smile 54
# a yellow and pink pokemon pikachu with big eyes 47
# a cartoon animal with a pink ball on its head 45
# a drawing of a volcano with a bird on top of it 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character with a sword in his hand 44
# a black and white picture of a cat wearing a witches hat 56
# a blue bird with a red and white beak 37
# a very cute looking bird with big wings 39
# a gray and black cat with yellow eyes 37
# a cartoon character with a tongue sticking out 46
# a pink bird sitting on top of a white surface 45
# a picture of a cartoon character on a cell phone 48
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character with a green hat 49
# an image of a cartoon character flying through the air 54
# a very cute looking cartoon character with big eyes 51
# a picture of a pink and yellow pokemon figure 45
# a blue robot with a cross on it's chest 39
# a pink butterfly with black wings and a white background 56
# a very cute looking pokemon with big wings 42
# a drawing of a dragon with a green and white tail 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a deer with antlers on it's head 45
# a colorful bird is standing on its hind legs 44
# a drawing of a furry white dog with red eyes 44
# a drawing of a cat wearing a purple hat 39
# a colorful bird flying through the air 38
# a pink and white cartoon character with wings 45
# a drawing of a purple and white pokemon 39
# a yellow and green animal with its mouth open 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character with horns and horns 53
# a blue jellyfish with red eyes and a red nose 45
# a cartoon sheep is kicking a soccer ball 40
# a cartoon blue bird with its mouth open 39
# a green and white cartoon character with a sword 48
# a drawing of a pokemon type pokemon type pokemon type pokemon type pokemon type pokemon type 92
# a pikachu holding a cell phone and wearing a bow tie 52
# a green and yellow spider with its tongue out 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a pink and black pokemon character 47
# a drawing of a pony with red hair 33
# a drawing of a cartoon character holding a large object 55
# a drawing of a blue and yellow dragon 37
# a cartoon character with a bat on his back 42
# a drawing of a fish with a long tongue 38
# a yellow bee with two eyes and two antennae 43
# a drawing of a cartoon character holding a surfboard 52
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character with a potted plant on his head 51
# a pink and yellow deer with a yellow bow on its head 52
# a yellow and brown pokemon pokemon character flying through the air 67
# a cartoon character with a scarf around his neck 48
# a cartoon character with a strange hair style 45
# a drawing of a gray and white dragon 36
# a cartoon bird with a green hat on its head 43
# a cartoon character with green eyes and a hat 45
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a picture of a white horse with orange and yellow flames 56
# a very cute looking animal with horns on it's head 50
# a drawing of a small animal with a pink nose 44
# a cartoon character with a backpack on his back 47
# a blue and white dragon with its mouth open 43
# a very cute looking cartoon character with big eyes 51
# a picture of a cartoon character with spoons and spoons 55
# a cartoon character with a weird look on his face 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a black and white animal with pink eyes 39
# a purple and blue dragon flying through the air 47
# a butterfly with a flag on it's wings 37
# a cartoon turtle with a tree on its back 40
# a green insect with two green eyes 34
# a black and white photo of a butterfly 38
# a blue pokemon character with yellow eyes and a white shirt 59
# a drawing of a cartoon character in a yellow outfit 51
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon cat is holding onto a leash 37
# an origami dog with a pink and blue body 40
# a drawing of a green and yellow dragon 38
# a drawing of a fire breathing dragon 36
# a drawing of a blue pokemon laying down 39
# a drawing of an octopus with a sad face 39
# a drawing of a cartoon character with wings 43
# a drawing of a pokemon pokemon character 40
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon dog is standing in a pose 35
# a cartoon elephant with a star on its back 42
# a drawing of a blue and red dragon 34
# a drawing of a very cute looking caterpillar 44
# a stylized image of a blue and brown robot 42
# a very cute looking pokemon with big eyes 41
# a blue and black chandelier with flames coming out of it 56
# a drawing of a blue dragon with red eyes 40
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a pumpkin with a bird on top of it 47
# a cartoon character with a mushroom on his head 47
# a cartoon character with a purple hat and purple hair 53
# a drawing of a purple and green pokemon 39
# a cartoon picture of a pink and gray dinosaur 45
# a yellow and black pokemon with big blue eyes 45
# a green and white stuffed animal wearing a green hat 52
# a blue and white cartoon character running 42
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a red cartoon character laying on the ground 44
# a cartoon character with a pink nose sitting in a pile of rocks 63
# a cartoon of a purple sea creature with its mouth open 54
# a cartoon character is holding a large object 45
# a drawing of an angry looking animal with red and purple stripes 64
# a white and purple cartoon character with green eyes 52
# a drawing of a yellow and gray pokemon character 48
# a drawing of a pink bird flying through the air 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a turtle holding a roll of toilet paper 52
# a cartoon picture of a small furry animal 41
# a very cute looking cartoon character with big eyes 51
# a blue and white pokemon type pokemon type pokemon type pokemon type pokemon type pokemon type 94
# a drawing of a red creature with yellow eyes 44
# a cartoon of a man with his arms in the air 43
# a drawing of a purple and white pokemon 39
# a drawing of a cartoon character with big eyes 46
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a brown and black animal with a white background 48
# a black and white zebra standing next to a star 47
# a cartoon of a pikachu with a leaf on its head 46
# a drawing of a blue dinosaur with wings 39
# a drawing of a cartoon character in a striped outfit 52
# a drawing of a bug with a re 28
# a cartoon character with a fire on his back 43
# a cartoon character with a crown on his head 44
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a pokemon with a hat on top of it 46
# a drawing of a bison with horns and horns 41
# a yellow and black tie and a purple and white tie 49
# a cartoon elephant with a backpack on it's back 47
# a cartoon giraffe sitting down with its eyes wide open 54
# a yellow bird flying through the air 36
# a green and yellow pokemon character 36
# a blue and orange fish with its mouth open 42
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon character flying through the air 42
# a blue and black object with two eyes 37
# a black and yellow pokemon type animal 38
# a very cute looking pokemon character with big eyes 51
# a drawing of a green creature with its mouth open 49
# a drawing of a cartoon character laying on the ground 53
# a cartoon turtle with a helmet on its head 42
# a very cute looking animal with big eyes 40
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a blue and brown turtle 36
# a drawing of a key with a face on it 36
# a cartoon character holding onto a ring 39
# a pokemon ball with a bird on top of it 39
# a drawing of a cartoon character wearing a green hat 52
# a cartoon character with an evil look on his face 49
# a very cute looking cartoon character with big eyes 51
# a very cute looking cartoon character with big eyes 51
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a woman in a red cape 34
# a drawing of a pink cat with big blue eyes 42
# a green and orange cartoon character 36
# a drawing of a white and blue pokemon 37
# a cartoon character with a cat like body 40
# a drawing of a dragon sitting on its hind legs 46
# a blue bird flying through the air with clouds 46
# a pink and black bird with a pink tail 38
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a couple of gears with eyes on them 35
# a drawing of a purple eggplant with a green leaf 48
# a very cute looking pokemon sitting on top of a rock 52
# a very cute looking animal with horns on it's head 50
# a drawing of a flying object with green eyes 44
# a cartoon bear with a ring around its neck 42
# a drawing of a white and black pokemon 38
# a drawing of a cartoon character with his hands on his hips 59
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a white and green pokemon pokemon character 43
# a couple of gears sitting next to each other 44
# a blue and black bat with black wings 37
# a yellow and white cartoon character with a red eye 51
# a pink and white cartoon animal with a yellow tail 50
# a brown and white animal with a pink nose 41
# a drawing of a cat with green eyes 34
# a cartoon of a red monster with a flame coming out of it's mouth 64
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue cartoon character holding a star 39
# a drawing of a white and red pokemon 36
# a drawing of a ball with spikes on it 37
# a drawing of a small animal with green leaves 45
# a very cute looking pokemon with big eyes 41
# a drawing of a blue dragon with yellow eyes 43
# a drawing of a green and black pokemon 38
# a picture of a fish with a red eye 34
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a green bird with a red tail and a black nose 45
# a cartoon bird with a bandanna on its head 42
# a drawing of a purple dragon with spikes on it's head 53
# a green and black bird with spots on it's wings 47
# a picture of a pink monster with green eyes 43
# a green and yellow bird with big eyes 37
# a drawing of a shark with its mouth open 40
# a drawing of a pink bird with black eyes 40
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon turtle sitting on top of a red ball 45
# a cartoon character is holding a banana 39
# a cartoon character is holding a baseball bat 45
# a cartoon character sitting on top of a green leaf 50
# a red and yellow pokemon pokemon character 42
# a cartoon character with an angry look on his face 50
# a drawing of a blue and black pokemon 37
# a blue sea horse with a yellow tail 35
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a cartoon character doing a kick 45
# a drawing of a black and white cat 34
# a very cute looking pokemon pikachu with big eyes 49
# a drawing of a very cute looking pokemon 40
# a drawing of a fish with a blue and yellow face 47
# a drawing of a cartoon character with arms and legs 51
# a cartoon character with two eyes and a mouth open 50
# a drawing of a creature with a big smile on its face 52
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue and white cartoon character with red eyes 48
# a blue and white cartoon character with a crown on his head 59
# a cartoon character with a green leaf on top of it 50
# a green and yellow animal with a yellow bow on its head 55
# a drawing of a white and black animal with blue eyes 52
# a blue and yellow dragon with its mouth open 44
# a drawing of a yellow and black cat 35
# a red cartoon character is flying through the air 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a blue bird flying through the sky with clouds 46
# a cartoon bird with a scarf around its neck 43
# a very cute looking pokemon with big wings 42
# a cartoon character in grey and yellow 38
# a drawing of a blue and yellow dragon 37
# a picture of a cartoon character in a costume 45
# a drawing of a star with a jewel in the center 46
# a drawing of a cartoon character with blonde hair 49
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a drawing of a purple creature with a big smile on it's face 60
# a drawing of a cartoon dinosaur with its mouth open 51
# a blue cartoon character with a red nose and ears 49
# a black and white animal with a lightning bolt on its head 58
# a cartoon of a green tree with leaves 37
# a drawing of a cartoon character with two eyes 46
# a drawing of a blue and white fish 34
# a drawing of a cartoon character with blue eyes 47
# Shape before linear layer: torch.Size([8, 3, 256, 256])
# a cartoon bird flying through the air 37
# a drawing of a blue and red dragon 34
# a pink butterfly with a black and white stripe on it's wings 60
# a cartoon character with a pink and blue tail 45
# a blue cartoon character with its mouth open 44
# a drawing of a red and black pokemon 36
# a cartoon blue fish with a yellow fin 37
# a drawing of an animal with blue eyes 37
# Shape before linear layer: torch.Size([8, 3, 256, 256])
